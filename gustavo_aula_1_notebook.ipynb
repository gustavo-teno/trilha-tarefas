# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavo-teno/trilha-tarefas/blob/main/gustavo_aula_1_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⛰ ***Exercícios - Aula 1***

# %% [markdown]
# ## Questão 1 📝
#
# Corrija o código abaixo para que ele funcione sem erros:
#
# ```bash
# numero = 5
# print("O número é " + numero)
# ```

# %%
#eu gosto de separar os argumentos com ,
numero = 5
print("O número é",numero)

#usando str()
numero = 10
print("O número é " + str(numero))

#usando f-string
numero = 15
print(f"O número é {numero}")
# Out:
# O número é 5
# O número é 10
# O número é 15

# %% [markdown]
# ### 💡Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Não é possível concatenar `str` com `int` usando `+`. Use `str()` para converter, ou use f-string.*

# %% [markdown]
# ## Questão 2 📝
#
# Faça uma calculadora simples. Peça ao usuário para digitar 2 números via `input()` e exiba o resultado das 4 operações básicas, cada uma em um `print()` separado.

# %%
numero = float(input("Digite um número: "))
outro_numero = float(input("Digite outro número: "))

soma = numero + outro_numero
sub = numero - outro_numero
mult = numero * outro_numero
div = numero / outro_numero

print("\nOperações básicas")
print(f"\nSoma: {numero} + {outro_numero} = {soma}")
print(f"\nSubtração: {numero} - {outro_numero} = {sub}")
print(f"\nMultiplicação: {numero} x {outro_numero} = {mult}")
print(f"\nDivisão: {numero} / {outro_numero} = {div}")
# Out:
# Digite um número: 5
# Digite outro número: 4
#
# Operações básicas
#
# Soma: 5.0 + 4.0 = 9.0
#
# Subtração: 5.0 - 4.0 = 1.0
#
# Multiplicação: 5.0 x 4.0 = 20.0
#
# Divisão: 5.0 / 4.0 = 1.25

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *`input()` retorna string. Converta para `int` ou `float` antes de operar.*

# %% [markdown]
# ## Questão 3 📝
#
# Dada a string abaixo, use métodos de string para:
# 1. Imprimir em maiúsculas
# 2. Imprimir em minúsculas
# 3. Imprimir somente os primeiros 6 caracteres (slicing)
# 4. Verificar se a palavra `"Python"` está contida na frase
#
# **Código inicial:**
#
# ```bash
# frase = "Python é incrível"
#
# # 1. maiúsculas
# # 2. minúsculas
# # 3. primeiros 6 caracteres
# # 4. verificar se "Python" está na frase
# ```

# %%
frase = "Python é incrível"

# 1. maiúsculas
print(frase.upper())
# 2. minúsculas
print(frase.lower())
# 3. primeiros 6 caracteres
print(frase[:6])
# 4. verificar se "Python" está na frase
print("Python" in frase)
# Out:
# PYTHON É INCRÍVEL
# python é incrível
# Python
# True

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Use `.upper()`, `.lower()`, fatiamento com `[:6]` e o operador `in`.*

# %% [markdown]
# ## Questão 4 📝
#
# Peça ao usuário para digitar a base e a altura de um triângulo e calcule a área.
#
# **Fórmula:** `Área = (base * altura) / 2`
#
# Exiba o resultado usando f-string.

# %%
print("- Calculadora - Área de Triângulo - \n")

base = float(input("Digite o valor da base = "))
altura = float(input("\nDigite o valor da altura = "))

area = (base * altura) / 2
print(f"\nO triângulo de base {base}, com altura {altura}, possui área = {area}")
# Out:
# - Calculadora - Área de Triângulo -
#
# Digite o valor da base = 5
#
# Digite o valor da altura = 4
#
# O triângulo de base 5.0, com altura 4.0, possui área = 10.0

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Não esqueça de converter o `input()` para `float`.*

# %% [markdown]
# ## Questão 5  📝
#
# Peça ao usuário para digitar uma nota (0 a 10) e classifique usando `if`/`elif`/`else`:
#
# - Nota >= 7: `"Aprovado"`
# - Nota >= 5: `"Recuperação"`
# - Nota < 5: `"Reprovado"`

# %%
nota = float(input("Digite uma nota: "))

if nota > 10.0 or nota < 0.0:
  print("Nota inválida")
elif nota >= 7:
  print("Aprovado")
elif nota >= 5:
  print("Recuperação")
else:
  print("Reprovado")
# Out:
# Digite uma nota: 6.98
# Recuperação

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Atenção à ordem das condições, se entrar no primeiro if, o resto das condicionais será pulado. Comece sempre pelo maior valor.*

# %% [markdown]
# ## Questão 6 📝
#
# Crie um programa que recebe o salário de um funcionário e calcula o imposto devido com base nas faixas abaixo:
#
# | Faixa salarial | Alíquota |
# |---|---|
# | Até R\$ 1.500 | Isento (0%) |
# | R\$ 1.500,01 – R\$ 3.000 | 7,5% |
# | R\$ 3.000,01 – R\$ 4.500 | 15% |
# | Acima de R\$ 4.500 | 22,5% |
#
# Exiba o salário bruto, o valor do imposto e o salário líquido.

# %%
salario = float(input("Salário = "))

if salario < 0:
  print("Salário inválido")

else:
  if salario >= 0 and salario <= 1500:
    aliquota = 0
  elif salario <= 3000:
    aliquota = 0.075
  elif salario <= 4500:
    aliquota = 0.15
  else:
    aliquota = 0.225

  imposto = (salario * aliquota)
  liquido = salario - imposto

  print(f"\nSalário bruto = {salario:.2f}")
  print(f"\nImposto = {imposto:.2f}")
  print(f"\nSalário líquido = {liquido:.2f}")
# Out:
# Salário = 3000
#
# Salário bruto = 3000.00
#
# Imposto = 225.00
#
# Salário líquido = 2775.00

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Use `if`/`elif`/`else` para cada faixa. Calcule `imposto = salario * aliquota`, depois `liquido = salario - imposto`. *

# %% [markdown]
# ## Questão 7 📝
#
# Crie um programa que verifica se um ano digitado pelo usuário é bissexto.
#
# **Regras:**
# - Divisível por 4 → bissexto
# - Mas se divisível por 100 → **NÃO** é bissexto
# - A menos que também seja divisível por 400 → **É** bissexto
#
# Exiba `"Ano bissexto"` ou `"Não é bissexto"`.

# %%
ano = int(input("Ano = "))

if ano % 4 == 0:
  if ano % 100 == 0 and ano % 400 != 0:
    print("Não é bissexto")
  else:
    print("Ano bissexto")
else:
  print("Não é bissexto")
# Out:
# Ano = 2026
# Não é bissexto

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Use o operador `%` para verificar divisibilidade. Combine condições com `and` e `or`.*

# %% [markdown]
# ## Questão 8 📝
#
# Construa um programa que recebe o peso e a altura do usuário, calcula o IMC e classifica o resultado:
#
# | IMC | Classificação |
# |---|---|
# | IMC < 18,5 | Abaixo do peso |
# | 18,5 <= IMC < 25 | Peso normal |
# | 25 <= IMC < 30 | Sobrepeso |
# | IMC >= 30 | Obesidade |
#
# Exiba o IMC com 2 casas decimais e a classificação.

# %%
peso = float(input("Peso (kg) = "))
altura = float(input("Altura (m) = "))

if peso <= 0 or altura <= 0:
  print("\nValores inválidos")

else:
  imc = peso/(altura**2)

  if imc < 18.5:
    print(f"\nIMC = {imc:.2f} | Abaixo do peso")

  elif imc < 25:
    print(f"\nIMC = {imc:.2f} | Peso normal")

  elif imc < 30:
    print(f"\nIMC = {imc:.2f} | Sobrepeso")

  else:
    print(f"\nIMC = {imc:.2f} | Obesidade")
# Out:
# Peso (kg) = 67
# Altura (m) = 1.74
#
# IMC = 22.13 | Peso normal

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *`IMC = peso / altura**2`. Para formatar com 2 casas decimais, use `f"{imc:.2f}"`.*

# %% [markdown]
# ## Questão 9 📝
#
# Peça ao usuário para digitar uma palavra e use métodos de string para:
# 1. Exibir com a primeira letra maiúscula
# 2. Exibir quantas letras ela tem
# 3. Exibir a palavra de trás para frente (slicing reverso)
# 4. Verificar se ela começa com a letra `"a"` (sem diferenciar maiúsculas de minúsculas)

# %%
palavra = input("Digite uma palavra: ")

#exibir com a primeira letra maiúscula
print(palavra.capitalize())

#exibir quantas letras ela tem
print(len(palavra))

#exibir de trás para frente
print(palavra[::-1])

#verificar se começa com a letra "a"
print(palavra.lower().startswith("a"))
# Out:
# Digite uma palavra: trilha
# Trilha
# 6
# ahlirt
# False

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Use `.capitalize()`, `len()`, slicing `[::-1]` e `.lower().startswith("a")`.*

# %% [markdown]
# ## Questão 10 📝
#
# Crie um classificador de triângulos. Receba os 3 lados pelo `input()` e:
#
# 1. Verifique se os lados formam um triângulo válido *(a soma de dois lados quaisquer deve ser maior que o terceiro)*
# 2. Se válido, classifique:
#    - **Equilátero:** todos os lados iguais
#    - **Isósceles:** dois lados iguais
#    - **Escaleno:** todos diferentes
#
# Exiba a classificação ou `"Não forma um triângulo"`.

# %%
lado_um = float(input("Lado 1 = "))
lado_dois = float(input("Lado 2 = "))
lado_tres = float(input("Lado 3 = "))

#usei uma lógica distinta da fornecida na dica
if lado_um >= lado_dois + lado_tres or lado_dois >= lado_um + lado_tres or lado_tres >= lado_um + lado_dois:
  print("\nNão forma um triângulo")
else:
  if lado_um == lado_dois == lado_tres:
    print("Equilátero")
  elif lado_um == lado_dois != lado_tres or lado_dois == lado_tres != lado_um or lado_tres == lado_um != lado_dois:
    print("Isósceles")
  else:
    print("Escaleno")
# Out:
# Lado 1 = 3
# Lado 2 = 4
# Lado 3 = 5
# Escaleno

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Condição de triângulo válido: `a+b>c AND a+c>b AND b+c>a`. Depois compare os lados com `==` para classificar.*
